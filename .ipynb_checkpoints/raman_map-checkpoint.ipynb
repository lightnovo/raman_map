# %%
import numpy as np
import json
import os
import math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
from scipy.optimize import curve_fit
from __future__ import print_function
from scipy import stats

# %%
sns.set(font_scale=1.5)

# %%
class time_series:
    def __init__(self,fname):
        self.fname = fname
        self.fname0 = self.fname.split('/')[-1]
        with open(fname + ".json", 'r') as f: 
            metadata = json.load(f);
            self.shape = metadata['spectraDimensions']['Shape']
            self.nx = self.shape[1]
            self.ny = self.shape[0]
            self.nwn = self.shape[2]
            
            axescoords = metadata['spectraDimensions']['AxesCoords']
            self.x = axescoords[1]
            self.y = axescoords[0]
            self.wn = axescoords[2]
        with open(fname + ".mrspectra", 'rb') as f:    
               buf = f.read()
        if len(buf) < 4*np.prod(self.shape):
            print("Incomplete file, adding zeros to the end")
            buf += b'\0'*(4*np.prod(self.shape) - len(buf))
        data = np.frombuffer(buf, dtype=np.single, count=np.prod(self.shape))
        self.data = data.reshape(self.shape)             
                
    def plot_map_normal(self, wavenumber,halfwidth):
        array = []
        halfwidth = int(halfwidth)
        for j in reversed(range(self.ny)):
            for i in range(self.nx):
                array = np.append(array,np.average(self.data[j][i][wavenumber-50-halfwidth:wavenumber-50+halfwidth+1]))
        array = np.reshape(array, (-1, self.nx))
        df = pd.DataFrame(array,columns = self.x, index = self.y)

        plt.imshow(df, cmap ="jet") 
        plt.colorbar()
        #plt.xticks(range(len(df)), df.columns) #can be used for smaller maps
        #plt.yticks(range(len(df)), df.index) # can be used for smaller maps
        plt.xticks(np.round(np.linspace(0,self.nx,num = 5),3),np.round(np.linspace(min(self.x),max(self.x),num = 5),3)) # for bigger maps
        plt.yticks(np.round(np.linspace(0,self.ny,num = 5),3),reversed(np.round(np.linspace(min(self.y),max(self.y),num = 5),3))) # for bigger maps
        plt.xlabel("x, mm")
        plt.ylabel("y, mm")
        plt.grid(False)
        plt.title(str(wavenumber)+" nm")
        plt.show()

# %%
home_dir = "C:/Users/sofus/"
dir_path = home_dir + "Data/polystyrene beads/"

# %%
files = os.listdir(dir_path)

# %%
files
# Out:
# ['1um_polystyrene_beads_100xobjective_113mw_36x31_200nmStep_785nm.json',
#  '1um_polystyrene_beads_100xobjective_113mw_36x31_200nmStep_785nm.mrspectra',
#  '1um_polystyrene_beads_100xobjective_113mw_71x71_200nmStep_785nm.json',
#  '1um_polystyrene_beads_100xobjective_113mw_71x71_200nmStep_785nm.mrspectra',
#  '1um_polystyrene_beads_100xobjective_113mw_71x71_200nmStep_second_785nm.json',
#  '1um_polystyrene_beads_100xobjective_113mw_71x71_200nmStep_second_785nm.mrspectra',
#  '59x61_500umStep_polysterene_beads_50objective_113mw_1001wn_5width_785nm.png',
#  'calcium_fluoride_polystyrene_beads_biggertest_785nm.json',
#  'calcium_fluoride_polystyrene_beads_biggertest_785nm.mrspectra',
#  'calcium_fluoride_polystyrene_beads_biggertest_785nm_50objective_113mw.json',
#  'calcium_fluoride_polystyrene_beads_biggertest_785nm_50objective_113mw.mrspectra',
#  'calcium_fluoride_polystyrene_beads_smalltest_785nm.json',
#  'calcium_fluoride_polystyrene_beads_smalltest_785nm.mrspectra',
#  'calcium_fluoride_polystyrene_beads_zscan_113mw_785nm.json',
#  'calcium_fluoride_polystyrene_beads_zscan_113mw_785nm.mrspectra',
#  'calcium_fluoride_polystyrene_beads_zscan_113mw_fast_785nm.json',
#  'calcium_fluoride_polystyrene_beads_zscan_113mw_fast_785nm.mrspectra']

# %%
# Raman maps
files1 = [f.split('.')[0] for f in files if ".json" in f]
files1
# Out:
# ['1um_polystyrene_beads_100xobjective_113mw_36x31_200nmStep_785nm',
#  '1um_polystyrene_beads_100xobjective_113mw_71x71_200nmStep_785nm',
#  '1um_polystyrene_beads_100xobjective_113mw_71x71_200nmStep_second_785nm',
#  'calcium_fluoride_polystyrene_beads_biggertest_785nm',
#  'calcium_fluoride_polystyrene_beads_biggertest_785nm_50objective_113mw',
#  'calcium_fluoride_polystyrene_beads_smalltest_785nm',
#  'calcium_fluoride_polystyrene_beads_zscan_113mw_785nm',
#  'calcium_fluoride_polystyrene_beads_zscan_113mw_fast_785nm']

# %%
ts0 = time_series( dir_path + files1[2])

# %%
ts0.plot_map_normal(1000,0)

# %%
ts0.data[0][0][995:1006]
# Out:
# array([ 0.00733981,  0.00116947, -0.00854389, -0.02269009, -0.02452624,
#        -0.00443125,  0.00926347,  0.00576143,  0.00113446,  0.00276933,
#         0.00840268], dtype=float32)

# %%
ts0.data[0][0][1000]
# Out:
# -0.004431254
